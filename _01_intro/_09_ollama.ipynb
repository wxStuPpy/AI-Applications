# %%
from langchain_core.messages import HumanMessage
from langchain_ollama import ChatOllama

# %%
llm=ChatOllama(
    model='deepseek-r1:7b'
)

messages=[
    HumanMessage(content='1+1等于几'),
]

res=llm.invoke(messages)
print(res)
# Out:
# content='1 + 1 等于 **2**。' additional_kwargs={} response_metadata={'model': 'deepseek-r1:7b', 'created_at': '2025-10-22T05:31:25.1443729Z', 'done': True, 'done_reason': 'stop', 'total_duration': 64134858000, 'load_duration': 61299560600, 'prompt_eval_count': 8, 'prompt_eval_duration': 2096921000, 'eval_count': 17, 'eval_duration': 508314200, 'model_name': 'deepseek-r1:7b', 'model_provider': 'ollama'} id='lc_run--391b8449-5a37-4fc0-8ab6-93238a40de92-0' usage_metadata={'input_tokens': 8, 'output_tokens': 17, 'total_tokens': 25}
