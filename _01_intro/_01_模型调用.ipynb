# %%
import os

from langchain_openai import ChatOpenAI

model=ChatOpenAI(
    api_key="sk-9PaPWK9EDCr4w8N9NP54rIZoTak3RPnUq3oQToqdvTQSfUl1",
    base_url='https://api.openai-proxy.org/v1',
)
res=model.invoke('what is your name?')
print(res.content)
# Out:
# I am a language model AI and I don't have a specific name. You can call me Assistant. How can I help you today?
