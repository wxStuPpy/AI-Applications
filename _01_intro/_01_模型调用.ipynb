# %%
import os

from langchain_openai import ChatOpenAI

model=ChatOpenAI(
    api_key="sk-9PaPWK9EDCr4w8N9NP54rIZoTak3RPnUq3oQToqdvTQSfUl1",
    base_url='https://api.openai-proxy.org/v1',
)
res=model.invoke('what is your name?')
print(res.content)
# Out:
# I am an AI digital assistant, so I don't have a personal name. You can call me Assistant or simply ask me any questions you have. What can I help you with today?
