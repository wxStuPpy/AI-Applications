# %%
from langchain_core.prompts import load_prompt
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
prompt=load_prompt('prompt.yaml',encoding='utf-8')
# print(prompt)
print(prompt.format(name='aaa',what='hello'))
# Out:
# 请给aaa讲一个关于hello的故事

# %%
prompt=load_prompt('prompt.json',encoding='utf-8')
# print(prompt)
print(prompt.format(name='aaa',what='hello'))
# Out:
# 请aaa讲一个hello的故事。
